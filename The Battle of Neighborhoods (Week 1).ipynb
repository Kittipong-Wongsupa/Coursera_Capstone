# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# **1. A description of the problem and a discussion of the background.**

# %% [markdown]
# I am interested in the question about looking for the best location for coffee shop. I am in Ching Mai ,Thailand. This city have a coffee culture. there are many the coffee shop in here. There are some shop success. Too many had fail so, I was Thinking about location might be the main feature of sucess.
#
# The main problem is what is the best location for opene new cafe?
# Are ther relationship between other shop with cafe such as restaurant, hotel, shopping mall?

# %% [markdown]
# **2. A description of the data and how it will be used to solve the problem.**

# %% [markdown]
# The data from Foursquare. By use API search the coffee shop in Ching Mai

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
from geopy.geocoders import Nominatim 
from pandas.io.json import json_normalize 
import folium 
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
CLIENT_ID = 'RWRXM2YICPLI44BR4KDCQPC2XFJEPXE0EDK3KOKJ2VG2INBM' # your Foursquare ID
CLIENT_SECRET = 'XIAHRN0AMFCHQ1CF44MMBCIFPEKNFNZXQ2BC55BLNUYID5UU' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RWRXM2YICPLI44BR4KDCQPC2XFJEPXE0EDK3KOKJ2VG2INBM
# CLIENT_SECRET:XIAHRN0AMFCHQ1CF44MMBCIFPEKNFNZXQ2BC55BLNUYID5UU

# %%
url = 'https://api.foursquare.com/v2/venues/search?ll=18.7883,98.9853&client_id=RWRXM2YICPLI44BR4KDCQPC2XFJEPXE0EDK3KOKJ2VG2INBM&client_secret=XIAHRN0AMFCHQ1CF44MMBCIFPEKNFNZXQ2BC55BLNUYID5UU&v=20180604&query=coffee'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcce94a5b23bb233076a781'},
#  'response': {'venues': [{'id': '4b5c40cff964a520ad2829e3',
#     'name': 'Ratchadumnern Coffee (กาแฟราชดำเนิน)',
#     'location': {'address': 'Ratchadamnoen Road, Sriphum',
#      'lat': 18.788246,
#      'lng': 98.98533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788246,
#        'lng': 98.98533}],
#      'distance': 6,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchadamnoen Road, Sriphum',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '51b98562498eb59c591d4139',
#     'name': 'Akha Ama Coffee La Fattoria',
#     'location': {'address': 'Ratchadamnoen Rd',
#      'lat': 18.788392505611224,
#      'lng': 98.98331384416873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788392505611224,
#        'lng': 98.98331384416873}],
#      'distance': 209,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchadamnoen Rd',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4d8475f05e70224bac0a0d09',
#     'name': 'Pacamara Boutique Coffee Roasters (ร้านกาแฟ พาคามาร่า)',
#     'location': {'address': '80/5 Ratchadamnoen Rd',
#      'lat': 18.788202119901143,
#      'lng': 98.98674622287517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788202119901143,
#        'lng': 98.98674622287517}],
#      'distance': 152,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['80/5 Ratchadamnoen Rd',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5a891a66d7627e4ebd3b8737',
#     'name': 'Chiangmai Coffee Bean',
#     'location': {'lat': 18.78911,
#      'lng': 98.98793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78911,
#        'lng': 98.98793}],
#      'distance': 291,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เทศบาลนครเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['เทศบาลนครเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4b6e594bf964a52097b92ce3',
#     'name': 'Wawee Coffee (กาแฟวาวี)',
#     'location': {'address': 'Ratchadamnoen Rd.',
#      'crossStreet': 'at Kad Klang Wiang',
#      'lat': 18.787975096863644,
#      'lng': 98.99017761023494,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.787975096863644,
#        'lng': 98.99017761023494}],
#      'distance': 515,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchadamnoen Rd. (at Kad Klang Wiang)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '50a84b19e4b0f10a1b0bf9f3',
#     'name': 'KALDI Coffee',
#     'location': {'address': '145/4 Ratchadamnoen Rd',
#      'lat': 18.788208605747897,
#      'lng': 98.98679597328102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788208605747897,
#        'lng': 98.98679597328102}],
#      'distance': 157,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['145/4 Ratchadamnoen Rd',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4d53a54c08a7b1f7ae733492',
#     'name': 'Baanlansa Coffee & Guest House บ้านลานสา',
#     'location': {'lat': 18.788539255705924,
#      'lng': 98.98325890799643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788539255705924,
#        'lng': 98.98325890799643}],
#      'distance': 216,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'shortName': 'B & B',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4e81b119be7b86178ef6fcac',
#     'name': 'Tree Sis Coffee (ทรี ซิส คอฟฟี่)',
#     'location': {'address': 'Intrawarorot Rd',
#      'lat': 18.78945515760821,
#      'lng': 98.98260212353637,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78945515760821,
#        'lng': 98.98260212353637}],
#      'distance': 312,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Intrawarorot Rd',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '58634f26158b961788c6dafe',
#     'name': 'Coffee Telling (ให้กาแฟพูด)',
#     'location': {'address': 'Ratchapakinai Road, Sri Phum',
#      'crossStreet': 'Ratvithi Road',
#      'lat': 18.790343,
#      'lng': 98.9902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.790343,
#        'lng': 98.9902}],
#      'distance': 564,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchapakinai Road, Sri Phum (Ratvithi Road)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4da41bc89935a093cc11d66f',
#     'name': 'Coffee Mail',
#     'location': {'lat': 18.786105,
#      'lng': 98.982108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.786105,
#        'lng': 98.982108}],
#      'distance': 415,
#      'cc': 'TH',
#      'city': 'Sri Phum',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Sri Phum', 'เชียงใหม่', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5173fcdae4b05b6431fe5c4e',
#     'name': 'The Coffee Club',
#     'location': {'lat': 18.787854667951258,
#      'lng': 98.99298112760518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.787854667951258,
#        'lng': 98.99298112760518}],
#      'distance': 811,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['เมืองเชียงใหม่', 'เชียงใหม่ 50200', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4cfee8430457b1f7eb472978',
#     'name': 'Thorphan Coffee & Break',
#     'location': {'address': 'Back to Wat Phra Singha',
#      'crossStreet': 'Ratchamanka 8',
#      'lat': 18.78700200252152,
#      'lng': 98.98207408585432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78700200252152,
#        'lng': 98.98207408585432}],
#      'distance': 369,
#      'cc': 'TH',
#      'city': 'Sri Phum',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Back to Wat Phra Singha (Ratchamanka 8)',
#       'Sri Phum',
#       'เชียงใหม่',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4d8ad2186ce6a35d811c6942',
#     'name': 'Coffee Big',
#     'location': {'address': '239',
#      'crossStreet': 'Singharat',
#      'lat': 18.79304286417375,
#      'lng': 98.9820039654527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.79304286417375,
#        'lng': 98.9820039654527}],
#      'distance': 631,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'Sri Phum',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['239 (Singharat)',
#       'Sri Phum',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5703b31bcd101d4ac8734ae9',
#     'name': 'Coffee Corner (กาแฟหัวมุม)',
#     'location': {'crossStreet': 'Singharat',
#      'lat': 18.792988,
#      'lng': 98.981905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.792988,
#        'lng': 98.981905}],
#      'distance': 632,
#      'cc': 'TH',
#      'state': 'Chiangmai',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Singharat', 'Chiangmai', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '522e8d9311d23d3065d0bda6',
#     'name': 'Pern Coffee (เปิ่นกาแฟโบราณถุงกระดาษ)',
#     'location': {'lat': 18.79030210163023,
#      'lng': 98.98182057392793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.79030210163023,
#        'lng': 98.98182057392793}],
#      'distance': 429,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '55322140498ebecc19265944',
#     'name': 'ร้านกาแฟบุญรักษา Boonraksa Coffee by Wat Pansao',
#     'location': {'lat': 18.792310452173247,
#      'lng': 98.97791808765861,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.792310452173247,
#        'lng': 98.97791808765861}],
#      'distance': 896,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4dda0178ae60680f1544c32b',
#     'name': 'J.Ju Coffee (กาแฟเจจุ)',
#     'location': {'address': 'Ratchamanka Road, Sriphum',
#      'lat': 18.785549227237514,
#      'lng': 98.98989558219908,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.785549227237514,
#        'lng': 98.98989558219908}],
#      'distance': 573,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchamanka Road, Sriphum',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5164369ae4b0f3b55cb4dfde',
#     'name': 'Coffee Band (คอฟฟี่แบนด์)',
#     'location': {'address': '10/1 Chaiyapoom Rd',
#      'lat': 18.788766070084627,
#      'lng': 98.9936906213854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.788766070084627,
#        'lng': 98.9936906213854}],
#      'distance': 885,
#      'postalCode': '50300',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['10/1 Chaiyapoom Rd',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50300',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4f3206ede4b013bb07b6a41d',
#     'name': 'Coffee Shop @ Life In Town',
#     'location': {'address': '1/1 Tippanet Road, Haiya',
#      'lat': 18.780577875665497,
#      'lng': 98.98163178898044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.780577875665497,
#        'lng': 98.98163178898044}],
#      'distance': 942,
#      'postalCode': '50100',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['1/1 Tippanet Road, Haiya',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50100',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4f1e2ca7e4b06076a2d024dc',
#     'name': 'Wawee Coffee (กาแฟวาวี)',
#     'location': {'address': 'สวนดอก',
#      'lat': 18.78904514433276,
#      'lng': 98.97912368901326,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78904514433276,
#        'lng': 98.97912368901326}],
#      'distance': 656,
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['สวนดอก',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '59fd840d364d97702658cc54',
#     'name': 'Doppio Cult Cafe and Specialty Coffee Roasters (ดอปปิโอ ท่าแพ)',
#     'location': {'address': 'Thapae Road,',
#      'lat': 18.78830759125897,
#      'lng': 98.99664915877113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78830759125897,
#        'lng': 98.99664915877113}],
#      'distance': 1196,
#      'postalCode': '50000',
#      'cc': 'TH',
#      'city': 'Mueang',
#      'state': 'Chang Wat Chiang Mai',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Thapae Road,',
#       'Mueang',
#       'Chang Wat Chiang Mai 50000',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'private': True,
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4e100f867d8b4d5613cef41d',
#     'name': 'The Rich Coffee House (กาแฟริช)',
#     'location': {'address': 'Sri Phum Road',
#      'lat': 18.795251798624466,
#      'lng': 98.98891329273881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.795251798624466,
#        'lng': 98.98891329273881}],
#      'distance': 862,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Sri Phum Road',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '58b2880e80e1af1b2ce7879f',
#     'name': 'Caliente Coffee Roaster (กาเลียนเต้ คอฟฟี่ โรสเตอร์)',
#     'location': {'address': 'Arak Road, Sri Phum',
#      'crossStreet': 'Intawarorot Road',
#      'lat': 18.789218,
#      'lng': 98.978118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.789218,
#        'lng': 98.978118}],
#      'distance': 763,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Arak Road, Sri Phum (Intawarorot Road)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5677972a498eadfaaccb41c1',
#     'name': 'Jario Coffee (จาริโอ้ คอฟฟี่)',
#     'location': {'address': 'Prapokklao Road, Sriphum',
#      'lat': 18.79426,
#      'lng': 98.98735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.79426,
#        'lng': 98.98735}],
#      'distance': 697,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Prapokklao Road, Sriphum',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '55e6afa7498ea37d8baeec3d',
#     'name': 'Work End Coffee Bar (เวิร์คเอนด์คอฟฟี่บาร์)',
#     'location': {'address': 'Arak Road, Prasingh',
#      'crossStreet': 'Ratchamanka Road',
#      'lat': 18.786262,
#      'lng': 98.978248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.786262,
#        'lng': 98.978248}],
#      'distance': 777,
#      'postalCode': '50200',
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Arak Road, Prasingh (Ratchamanka Road)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่ 50200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '5111e95ae4b02ecb500ec4f0',
#     'name': 'Blind Coffee & Bakery',
#     'location': {'lat': 18.78736984675701,
#      'lng': 98.9782229500096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78736984675701,
#        'lng': 98.9782229500096}],
#      'distance': 752,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4f8541cde4b0a7ed056ded95',
#     'name': 'Hill Koff Coffee (ฮิลล์คอฟฟ์ คอฟฟี่)',
#     'location': {'address': 'เยื้องโรงพยาบาลช้างเผือก',
#      'crossStreet': 'Chang Phuak Soi 2,',
#      'lat': 18.79839539916944,
#      'lng': 98.98670887136457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.79839539916944,
#        'lng': 98.98670887136457}],
#      'distance': 1133,
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['เยื้องโรงพยาบาลช้างเผือก (Chang Phuak Soi 2,)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '550d0028498ea2dd2c73df54',
#     'name': 'Phu Sariang Coffee (กาแฟภูสะเรียง)',
#     'location': {'address': 'เลยสวนบวกหาดมานิดหน่อย',
#      'lat': 18.781366398441904,
#      'lng': 98.9823383863903,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.781366398441904,
#        'lng': 98.9823383863903}],
#      'distance': 832,
#      'cc': 'TH',
#      'state': 'Thailand',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['เลยสวนบวกหาดมานิดหน่อย', 'Thailand', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '544c9d56498e01e80ef299a3',
#     'name': 'Burkta Coffee (เบิกตา คอฟฟี่)',
#     'location': {'address': '7/2 Rachadamneon Soi 4',
#      'crossStreet': 'Munmueng soi 3',
#      'lat': 18.7864825995448,
#      'lng': 98.99160123708134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.7864825995448,
#        'lng': 98.99160123708134}],
#      'distance': 694,
#      'cc': 'TH',
#      'city': 'เมืองเชียงใหม่',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['7/2 Rachadamneon Soi 4 (Munmueng soi 3)',
#       'เมืองเชียงใหม่',
#       'เชียงใหม่',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False},
#    {'id': '4cf8d3b8d1dd721efd06a59b',
#     'name': 'Coffee Laos บ้านนฤมิตร',
#     'location': {'lat': 18.78927692111772,
#      'lng': 98.99587154388428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.78927692111772,
#        'lng': 98.99587154388428}],
#      'distance': 1119,
#      'cc': 'TH',
#      'city': 'Chang Moi',
#      'state': 'เชียงใหม่',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Chang Moi', 'เชียงใหม่', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607264586',
#     'hasPerk': False}]}}

# %%
map_CM = folium.Map(location=[18.7883, 98.9853], zoom_start=13)
map_CM
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
